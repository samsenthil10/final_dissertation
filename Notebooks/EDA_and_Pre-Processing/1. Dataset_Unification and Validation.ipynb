# %% [markdown]
# #### This marks the beginning of generating a dataset sampled every minute.

# %%
import os
import pandas as pd
from dateutil import parser

# %% [markdown]
# #### Find all the CSV files with the same name collected from each date.
#
#
# | **File Name**             | **Description**                                                                 |
# |---------------------------|---------------------------------------------------------------------------------|
# | **dataset.csv**            | All sensor data collected from PMS5003 Particulate Matter and Sensirion SCD30 Sensors |
# | **no2dataset.csv**         | NO2 sensor data collected from ULPSM-NO2 968-047                                |
# | **pm_aeroequal_data.csv**  | PM2.5 and PM10 sensor data collected from Aeroqual S500 Portable Air Quality Monitor |
# | **no2_aeroequal_data.csv** | NO2 sensor data collected from Aeroqual S500 Portable Air Quality Monitor        |
# | **iAnemometer.xls**        | Windspeed and Temperature collected from BTMETER BT-100 Anemometer               |

# %%
def find_csv_files(directory):
    pm_sensor_files = []
    no2_sensor_files = []
    pm_aeroequal_files = []
    no2_aeroequal_files = []
    anemometer_files = []
    
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.startswith("dataset.csv"):
                pm_sensor_files.append(os.path.join(root, file).replace("\\","/"))

            if file.startswith("no2dataset.csv"):
                no2_sensor_files.append(os.path.join(root, file).replace("\\","/"))

            if file.startswith("pm_aeroequal_data.csv"):
                pm_aeroequal_files.append(os.path.join(root, file).replace("\\","/"))

            if file.startswith("no2_aeroequal_data.csv"):
                no2_aeroequal_files.append(os.path.join(root, file).replace("\\","/"))

            if file.startswith("iAnemometer.xls"):
                anemometer_files.append(os.path.join(root, file).replace("\\","/"))

    return pm_sensor_files, no2_sensor_files, pm_aeroequal_files, no2_aeroequal_files, anemometer_files

# %% [markdown]
# ##### 1. Sort the files in increasing order of date
# ##### 2. The Anemometer files are in Excel, while the others are in CSV.
# ##### 3. The logic merges a particular sensor file for all dates into one master file.

# %%
def create_master_table(files):

    files.sort(key=lambda x: int(x.split('/')[-2].split('_')[1]))
    
    data_frames = []

    for f in files:
        
        if f.endswith('.csv'):
            df = pd.read_csv(f)
            df.columns = df.columns.str.strip()
            if 'Date Time' in df.columns:
                df[['Date', 'Time']] = df['Date Time'].apply(lambda x: pd.Series([parser.parse(x).strftime('%d-%m-%Y')
                                                                                  , parser.parse(x).strftime('%H:%M:%S')]))
                df.drop(columns=['Date Time'], inplace=True)
            else: 
                df['Date'] = df['Date'].apply(lambda x: parser.parse(x.replace(":","/")).strftime('%d-%m-%Y'))

        elif f.endswith('.xls'):
            df = pd.read_excel(f, header=1)
            date_str = f.split('/')[-2].replace('_', '-')
            df['Date'] = parser.parse(date_str).strftime('%d-%m-%Y')
            df.drop(columns=['ID'], inplace=True, errors='ignore')

        df['Time'] = df['Time'].apply(lambda x: parser.parse(x).strftime('%H:%M:%S'))
        df = df[['Date', 'Time'] + [col for col in df.columns if col not in ['Date', 'Time']]]
        data_frames.append(df)

    return pd.concat(data_frames, ignore_index=True)

# %%
directory_path = 'E:/Final Dissertation/'
pm_sensor_files, no2_sensor_files, pm_aeroequal_files, no2_aeroequal_files, anemometer_files  = find_csv_files(directory_path)

# %%
for item in pm_sensor_files:
    print("PM Sensor File:", item)
# Out:
# PM Sensor File: E:/Final Dissertation/Collected_Data/August_15_2024/dataset.csv
# PM Sensor File: E:/Final Dissertation/Collected_Data/August_16_2024/dataset.csv
# PM Sensor File: E:/Final Dissertation/Collected_Data/August_18_2024/dataset.csv
# PM Sensor File: E:/Final Dissertation/Collected_Data/August_19_2024/dataset.csv
# PM Sensor File: E:/Final Dissertation/Collected_Data/August_20_2024/dataset.csv
# PM Sensor File: E:/Final Dissertation/Collected_Data/August_21_2024/dataset.csv
# PM Sensor File: E:/Final Dissertation/Collected_Data/August_22_2024/dataset.csv

# %%
for item in no2_sensor_files:
    print("NO2 Sensor File:", item)
# Out:
# NO2 Sensor File: E:/Final Dissertation/Collected_Data/August_15_2024/no2dataset.csv
# NO2 Sensor File: E:/Final Dissertation/Collected_Data/August_16_2024/no2dataset.csv
# NO2 Sensor File: E:/Final Dissertation/Collected_Data/August_18_2024/no2dataset.csv
# NO2 Sensor File: E:/Final Dissertation/Collected_Data/August_19_2024/no2dataset.csv
# NO2 Sensor File: E:/Final Dissertation/Collected_Data/August_20_2024/no2dataset.csv
# NO2 Sensor File: E:/Final Dissertation/Collected_Data/August_21_2024/no2dataset.csv
# NO2 Sensor File: E:/Final Dissertation/Collected_Data/August_22_2024/no2dataset.csv

# %%
for item in pm_aeroequal_files:
    print("PM Aeroequal File:", item)
# Out:
# PM Aeroequal File: E:/Final Dissertation/Collected_Data/August_15_2024/pm_aeroequal_data.csv
# PM Aeroequal File: E:/Final Dissertation/Collected_Data/August_16_2024/pm_aeroequal_data.csv
# PM Aeroequal File: E:/Final Dissertation/Collected_Data/August_18_2024/pm_aeroequal_data.csv
# PM Aeroequal File: E:/Final Dissertation/Collected_Data/August_19_2024/pm_aeroequal_data.csv
# PM Aeroequal File: E:/Final Dissertation/Collected_Data/August_20_2024/pm_aeroequal_data.csv
# PM Aeroequal File: E:/Final Dissertation/Collected_Data/August_21_2024/pm_aeroequal_data.csv
# PM Aeroequal File: E:/Final Dissertation/Collected_Data/August_22_2024/pm_aeroequal_data.csv

# %%
for item in no2_aeroequal_files:
    print("NO2 Aeroequal File:", item)
# Out:
# NO2 Aeroequal File: E:/Final Dissertation/Collected_Data/August_15_2024/no2_aeroequal_data.csv
# NO2 Aeroequal File: E:/Final Dissertation/Collected_Data/August_16_2024/no2_aeroequal_data.csv
# NO2 Aeroequal File: E:/Final Dissertation/Collected_Data/August_18_2024/no2_aeroequal_data.csv
# NO2 Aeroequal File: E:/Final Dissertation/Collected_Data/August_19_2024/no2_aeroequal_data.csv
# NO2 Aeroequal File: E:/Final Dissertation/Collected_Data/August_20_2024/no2_aeroequal_data.csv
# NO2 Aeroequal File: E:/Final Dissertation/Collected_Data/August_21_2024/no2_aeroequal_data.csv
# NO2 Aeroequal File: E:/Final Dissertation/Collected_Data/August_22_2024/no2_aeroequal_data.csv

# %%
for item in anemometer_files:
    print("Anemometer File:", item)
# Out:
# Anemometer File: E:/Final Dissertation/Collected_Data/August_15_2024/iAnemometer.xls
# Anemometer File: E:/Final Dissertation/Collected_Data/August_16_2024/iAnemometer.xls
# Anemometer File: E:/Final Dissertation/Collected_Data/August_18_2024/iAnemometer.xls
# Anemometer File: E:/Final Dissertation/Collected_Data/August_19_2024/iAnemometer.xls
# Anemometer File: E:/Final Dissertation/Collected_Data/August_20_2024/iAnemometer.xls
# Anemometer File: E:/Final Dissertation/Collected_Data/August_21_2024/iAnemometer.xls
# Anemometer File: E:/Final Dissertation/Collected_Data/August_22_2024/iAnemometer.xls

# %%
pm_sensor_master_table = create_master_table(pm_sensor_files)
no2_sensor_master_table = create_master_table(no2_sensor_files)
pm_aeroequal_master_table = create_master_table(pm_aeroequal_files)
no2_aeroequal_master_table = create_master_table(no2_aeroequal_files)
anemometer_master_table = create_master_table(anemometer_files)

# %%
pm_sensor_master_table
# Out:
#             Date      Time  PM1.0 ug/m3 (ultrafine particles)  \
# 0     15-08-2024  14:38:00                                  3
# 1     15-08-2024  14:39:00                                  3
# 2     15-08-2024  14:40:00                                  3
# 3     15-08-2024  14:41:00                                  3
# 4     15-08-2024  14:42:00                                  3
# ...          ...       ...                                ...
# 2962  22-08-2024  19:11:09                                  4
# 2963  22-08-2024  19:12:09                                  4
# 2964  22-08-2024  19:13:09                                  3
# 2965  22-08-2024  19:14:09                                  3
# 2966  22-08-2024  19:15:09                                  3
#
#       PM2.5 ug/m3 (combustion particles, organic compounds, metals)  \
# 0                                                     4
# 1                                                     4
# 2                                                     4
# 3                                                     4
# 4                                                     4
# ...                                                 ...
# 2962                                                 11
# 2963                                                 12
# 2964                                                 11
# 2965                                                 11
# 2966                                                 10
#
#       PM10 ug/m3  (dust, pollen, mould spores)  PM1.0 ug/m3 (atmos env)  \
# 0                                            4                        3
# 1                                            4                        3
# 2                                            4                        3
# 3                                            4                        3
# 4                                            6                        3
# ...                                        ...                      ...
# 2962                                        13                        4
# 2963                                        13                        4
# 2964                                        12                        3
# 2965                                        12                        3
# 2966                                        13                        3
#
#       PM2.5 ug/m3 (atmos env)  PM10 ug/m3 (atmos env)  >0.3um in 0.1L air  \
# 0                           4                       4                 516
# 1                           4                       4                 546
# 2                           4                       4                 567
# 3                           4                       4                 597
# 4                           4                       6                 597
# ...                       ...                     ...                 ...
# 2962                       11                      13                 975
# 2963                       12                      13                1017
# 2964                       11                      12                1017
# 2965                       11                      12                1017
# 2966                       10                      13                1017
#
#       >0.5um in 0.1L air  >1.0um in 0.1L air  >2.5um in 0.1L air  \
# 0                    167                  30                   0
# 1                    174                  34                   0
# 2                    179                  36                   0
# 3                    184                  40                   0
# 4                    184                  40                   2
# ...                  ...                 ...                 ...
# 2962                 281                  67                  20
# 2963                 290                  79                  18
# 2964                 290                  79                  18
# 2965                 290                  79                  18
# 2966                 295                  77                  18
#
#       >5.0um in 0.1L air  >10um in 0.1L air  CO2 in ppm  Temperature in C  \
# 0                      0                  0      544.83             30.98
# 1                      0                  0      511.20             30.94
# 2                      0                  0      577.91             30.77
# 3                      0                  0      477.55             28.52
# 4                      2                  2      487.44             27.68
# ...                  ...                ...         ...               ...
# 2962                   2                  2      406.02             24.50
# 2963                   2                  2      405.49             24.36
# 2964                   2                  2      483.23             24.47
# 2965                   2                  2      478.44             24.44
# 2966                   4                  2      551.94             24.43
#
#       Relative Humidity
# 0                 48.65
# 1                 49.05
# 2                 49.73
# 3                 53.64
# 4                 55.65
# ...                 ...
# 2962              64.77
# 2963              65.31
# 2964              65.23
# 2965              65.13
# 2966              65.37
#
# [2967 rows x 17 columns]

# %%
no2_sensor_master_table
# Out:
#             Date      Time   NO2 ppb  NO2 µg/m³
# 0     15-08-2024  14:33:05  0.216462   0.413983
# 1     15-08-2024  14:34:11 -0.239692  -0.458411
# 2     15-08-2024  14:35:16  0.071096   0.135970
# 3     15-08-2024  14:36:21  0.972681   1.860253
# 4     15-08-2024  14:37:27  0.096102   0.183795
# ...          ...       ...       ...        ...
# 2631  22-08-2024  19:09:58  1.146366   2.192424
# 2632  22-08-2024  19:11:03  1.287635   2.462603
# 2633  22-08-2024  19:12:09  1.029305   1.968546
# 2634  22-08-2024  19:13:14  1.104797   2.112924
# 2635  22-08-2024  19:14:20  1.237881   2.367448
#
# [2636 rows x 4 columns]

# %%
pm_aeroequal_master_table
# Out:
#             Date      Time  Monitor ID  Location ID  PM10(ppm)  PM2.5(ppm)
# 0     15-08-2024  14:05:00           1            1      0.001       0.001
# 1     15-08-2024  14:06:00           1            1      0.001       0.001
# 2     15-08-2024  14:07:00           1            1      0.000       0.000
# 3     15-08-2024  14:08:00           1            1      0.001       0.001
# 4     15-08-2024  14:09:00           1            1      0.001       0.001
# ...          ...       ...         ...          ...        ...         ...
# 3042  22-08-2024  19:12:00           1            1      0.000       0.000
# 3043  22-08-2024  19:13:00           1            1      0.004       0.001
# 3044  22-08-2024  19:14:00           1            1      0.002       0.001
# 3045  22-08-2024  19:15:00           1            1      0.002       0.001
# 3046  22-08-2024  19:16:00           1            1      0.000       0.000
#
# [3047 rows x 6 columns]

# %%
no2_aeroequal_master_table
# Out:
#             Date      Time  Monitor ID  Location ID  NO2(ppm)
# 0     15-08-2024  14:05:00           2            1     0.000
# 1     15-08-2024  14:06:00           2            1     0.000
# 2     15-08-2024  14:07:00           2            1     0.000
# 3     15-08-2024  14:08:00           2            1     0.000
# 4     15-08-2024  14:09:00           2            1     0.000
# ...          ...       ...         ...          ...       ...
# 3028  22-08-2024  19:12:00           2            1     0.004
# 3029  22-08-2024  19:13:00           2            1     0.006
# 3030  22-08-2024  19:14:00           2            1     0.005
# 3031  22-08-2024  19:15:00           2            1     0.006
# 3032  22-08-2024  19:16:00           2            1     0.004
#
# [3033 rows x 5 columns]

# %%
anemometer_master_table
# Out:
#             Date      Time  Wind Value(km/h)  Temp Value(°C)
# 0     15-08-2024  15:13:29               0.0            25.6
# 1     15-08-2024  15:14:29               0.0            26.0
# 2     15-08-2024  15:15:29               0.0            25.3
# 3     15-08-2024  15:16:29               0.0            25.4
# 4     15-08-2024  15:17:29               1.8            25.4
# ...          ...       ...               ...             ...
# 2718  22-08-2024  19:12:07               0.3            21.9
# 2719  22-08-2024  19:13:07               0.0            21.9
# 2720  22-08-2024  19:14:07               0.0            21.9
# 2721  22-08-2024  19:15:07               0.0            21.8
# 2722  22-08-2024  19:16:07               0.0            21.8
#
# [2723 rows x 4 columns]

# %% [markdown]
# #### Saved as Master files in output directory in Master_Data.

# %%
master_location = "E:/Final Dissertation/Master_Data/"

pm_sensor_master_table.to_csv(master_location + "pm_sensor_master_table.csv", index=False)
no2_sensor_master_table.to_csv(master_location + "no2_sensor_master_table.csv", index=False)
pm_aeroequal_master_table.to_csv(master_location + "pm_aeroequal_master_table.csv", index=False)
no2_aeroequal_master_table.to_csv(master_location + "no2_aeroequal_master_table.csv", index=False)
anemometer_master_table.to_csv(master_location + "anemometer_master_table.csv", index=False)

# %% [markdown]
# #### To easily identify whether data was collected by sensor, aeroequal or council as well as reorder columns

# %%
column_mapping = {
    'PM2.5 ug/m3 (combustion particles, organic compounds, metals)': 'PM2.5_µg/m³_combustion_particles_organic_compounds_metals_sensor',
    'PM2.5(ppm)': 'PM2.5_mg/m³_aeroequal',
    'PM25': 'PM2.5_µg/m³_council',
    'PM10 ug/m3  (dust, pollen, mould spores)': 'PM10_µg/m³_dust_pollen_mould_spores_sensor',
    'PM10(ppm)': 'PM10_mg/m³_aeroequal',
    'PM10': 'PM10_µg/m³_council',
    'NO2 ppb': 'NO2_ppb_sensor',
    'NO2(ppm)': 'NO2_ppm_aeroequal',
    'NO2': 'NO2_µg/m³_council',
    'Wind Value(km/h)': 'Wind_value_km/h',
    'PM1.0 ug/m3 (ultrafine particles)': 'PM1.0_µg/m³_ultrafine_particles_sensor',
    'PM1.0 ug/m3 (atmos env)': 'PM1.0_µg/m³_atmos_env',
    'PM2.5 ug/m3 (atmos env)': 'PM2.5_µg/m³_atmos_env',
    'PM10 ug/m3 (atmos env)': 'PM10_µg/m³_atmos_env',
    '>0.3um in 0.1L air': 'GT_0.3um_in_0.1l_air',
    '>0.5um in 0.1L air': 'GT_0.5um_in_0.1l_air',
    '>1.0um in 0.1L air': 'GT_1.0um_in_0.1l_air',
    '>2.5um in 0.1L air': 'GT_2.5um_in_0.1l_air',
    '>5.0um in 0.1L air': 'GT_5.0um_in_0.1l_air',
    '>10um in 0.1L air': 'GT_10um_in_0.1l_air',
    'CO2 in ppm': 'CO2_in_ppm',
    'Temperature in C': 'Temperature_in_c',
    'Relative Humidity': 'Relative_humidity',
    'NO2 µg/m³': 'NO2_µg/m³_sensor',
    'Temp Value(°C)': 'Temp_value_°c',
    'NO': 'NO_µg/m³_council',
    'NOXasNO2': 'NOx_as_NO2_µg/m³_council',
    'NV10': 'NV10_µg/m³_council',
    'NV25': 'NV2.5_µg/m³_council',
    'V10': 'V10_µg/m³_council',
    'V25': 'V2.5_µg/m³_council'
}

final_columns = ['Date', 'Time'] + list(column_mapping.values())

# %%
def load_and_preprocess(file):
    df = pd.read_csv(file).rename(columns=str.strip)
    df['DateTime'] = pd.to_datetime(df.pop('Date') + ' ' + df.pop('Time'), format='%d-%m-%Y %H:%M:%S')
    return df.sort_values('DateTime')

# %% [markdown]
# #### The master files are merged with a tolerance of 29 seconds, choosing the nearest available value
# #### The DateTime is selected from the file with the second lowest number of records.

# %%
def perform_merge_sensor_aeroequal(tolerance_seconds, master_files):
    dfs = [load_and_preprocess(file) for file in master_files]
    tolerance = pd.Timedelta(seconds=tolerance_seconds)
    
    merged_df = dfs[0]
    for df in dfs[1:]:
        merged_df = pd.merge_asof(merged_df, df, on='DateTime', tolerance=tolerance, direction='nearest')
    
    merged_df.drop(columns=[col for col in merged_df if 'Location ID' in col or 'Monitor ID' in col], inplace=True)
    
    merged_df['Date'] = merged_df['DateTime'].dt.date
    merged_df['Time'] = merged_df['DateTime'].dt.time
    merged_df.drop(columns=['DateTime'], inplace=True)
    
    primary_columns = [
        'Date', 'Time',
        'PM2.5 ug/m3 (combustion particles, organic compounds, metals)',  
        'PM2.5(ppm)',  
        'PM10 ug/m3  (dust, pollen, mould spores)',  
        'PM10(ppm)',  
        'NO2 ppb',  
        'NO2(ppm)',
        'Wind Value(km/h)'
    ]
    
    final_df = merged_df[primary_columns + [col for col in merged_df if col not in primary_columns]]
    final_df = final_df.apply(lambda col: col.interpolate(method='linear') if col.dtype.kind in 'biufc' else col)
    final_df.rename(columns=column_mapping, inplace=True)
    
    return final_df

# %%
directory_path = 'E:/Final Dissertation/Master_Data/'
master_files = [os.path.join(directory_path, file) for file in [
    'anemometer_master_table.csv',
    'no2_aeroequal_master_table.csv',
    'no2_sensor_master_table.csv',
    'pm_aeroequal_master_table.csv',
    'pm_sensor_master_table.csv'
]]

# %% [markdown]
# #### Why tolerance = 29?
# #### 1. Tolerance of less than 29 generated NaN cells with 2723 records, meaning the nearest value was unavailable.
# #### 2. Tolerance greater than 29 had no impact.

# %%
tolerance = 29
final_df = perform_merge_sensor_aeroequal(tolerance, master_files)
final_df.to_csv('E:/Final Dissertation/Final_Dataset/Final_Dataset.csv', index=False)

# %% [markdown]
# #### This marks the end of generating a dataset sampled every minute.
# #### Although not utilized for the current problem statement, this Dataset will be helpful for future research.

# %% [markdown]
# #### This marks the beginning of generating a dataset sampled every hour, matching the council dataset.
# #### The Date Time column from Council is taken as reference, using the same logic as above but with the tolerance of 1 hour

# %%
council_df = pd.read_csv('E:/Final Dissertation/Final_Dataset/2024-08-14-240826181306.csv')
council_df['End Date'] = pd.to_datetime(council_df['End Date'].ffill(), format='%d-%m-%Y', errors='coerce')
council_df['End Time'] = council_df['End Time'].replace('24:00:00', '00:00:00')
council_df.loc[council_df['End Time'] == '00:00:00', 'End Date'] += pd.DateOffset(days=1)
council_df['DateTime'] = pd.to_datetime(council_df['End Date'].dt.strftime('%d-%m-%Y') + ' ' + council_df['End Time'], format='%d-%m-%Y %H:%M:%S')
numeric_cols = council_df.select_dtypes(include='number').columns
council_df = council_df.set_index('DateTime')[numeric_cols].resample('h').mean().reset_index()

# %%
def preprocess_master_df(file):
    df = pd.read_csv(file)
    df['DateTime'] = pd.to_datetime(df.pop('Date') + ' ' + df.pop('Time'), format='%d-%m-%Y %H:%M:%S')
    return df.set_index('DateTime').resample('h').mean().reset_index()

# %%
def perform_merge_sensor_aeroequal_council():

    anemometer_df = preprocess_master_df('E:/Final Dissertation/Master_Data/anemometer_master_table.csv')
    no2_aeroequal_df = preprocess_master_df('E:/Final Dissertation/Master_Data/no2_aeroequal_master_table.csv')
    no2_sensor_df = preprocess_master_df('E:/Final Dissertation/Master_Data/no2_sensor_master_table.csv')
    pm_aeroequal_df = preprocess_master_df('E:/Final Dissertation/Master_Data/pm_aeroequal_master_table.csv')
    pm_sensor_df = preprocess_master_df('E:/Final Dissertation/Master_Data/pm_sensor_master_table.csv')
    
    merged_df = anemometer_df
    for df in [no2_aeroequal_df, no2_sensor_df, pm_aeroequal_df, pm_sensor_df, council_df]:
        merged_df = pd.merge_asof(merged_df, df, on='DateTime', tolerance=pd.Timedelta(hours=1), direction='nearest')
    
    merged_df.rename(columns=column_mapping, inplace=True)
    merged_df = merged_df.dropna(subset=[col for col in merged_df.columns if '_council' not in col], how='all')
    
    merged_df['Date'] = merged_df['DateTime'].dt.date
    merged_df['Time'] = merged_df['DateTime'].dt.time
    merged_df.drop(columns=['DateTime'], inplace=True)

    return merged_df[final_columns].dropna()

# %%
final_df = perform_merge_sensor_aeroequal_council()
final_df.to_csv('E:/Final Dissertation/Final_Dataset/Final_Hourly_Dataset.csv', index=False)

# %%
expected_columns = list(column_mapping.values())

# %%
def generate_statistics(final_df, master_files):
    
    for col in expected_columns:
        if col not in final_df.columns:
            final_df[col] = pd.NA
    
    present_columns = [col for col in expected_columns if col in final_df.columns]
    
    final_stats = final_df[present_columns].describe().T[['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max']]

    master_stats_combined = pd.DataFrame()
    for file_path in master_files:
        df = pd.read_csv(file_path)
        df.columns = [col.strip() for col in df.columns]
        
        df.rename(columns=column_mapping, inplace=True)
        
        common_columns = [col for col in present_columns if col in df.columns]
        if common_columns:
            stats = df[common_columns].describe().T[['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max']]
            master_stats_combined = pd.concat([master_stats_combined, stats])

    master_stats_combined = master_stats_combined.reindex(present_columns)
    
    return final_stats, master_stats_combined

# %%
directory_path = 'E:/Final Dissertation/Master_Data/'

master_files = [os.path.join(directory_path, file) for file in [
    'anemometer_master_table.csv',
    'no2_aeroequal_master_table.csv',
    'no2_sensor_master_table.csv',
    'pm_aeroequal_master_table.csv',
    'pm_sensor_master_table.csv'
]]

final_df = pd.read_csv('E:/Final Dissertation/Final_Dataset/Final_Dataset.csv')
final_hourly_df = pd.read_csv('E:/Final Dissertation/Final_Dataset/Final_Hourly_Dataset.csv')
final_stats, master_stats_combined = generate_statistics(final_df, master_files)
final_hourly_stats, _ = generate_statistics(final_hourly_df, master_files)

# %% [markdown]
# #### This marks the end of generating a dataset sampled every hour.

# %% [markdown]
# ##### 1. Statistics to see how the merged files are different from the master files combined.
# ##### 2. NaN, in this case, is not available in the file
# ##### 3. Council columns are not present in the master file and Final Dataset sampled every minute
# ##### 4. Some Sensor Columns are not present in the council file

# %%
comparison_count = pd.DataFrame({
    'Final Dataset Count': final_stats['count'],
    'Final Hourly Dataset Count': final_hourly_stats['count'],
    'Master Files Combined Count': master_stats_combined['count']
})
comparison_count.reindex(expected_columns)
# Out:
#                                                     Final Dataset Count  \
# PM2.5_µg/m³_combustion_particles_organic_compou...               2723.0
# PM2.5_mg/m³_aeroequal                                            2723.0
# PM2.5_µg/m³_council                                                 NaN
# PM10_µg/m³_dust_pollen_mould_spores_sensor                       2723.0
# PM10_mg/m³_aeroequal                                             2723.0
# PM10_µg/m³_council                                                  NaN
# NO2_ppb_sensor                                                   2723.0
# NO2_ppm_aeroequal                                                2723.0
# NO2_µg/m³_council                                                   NaN
# Wind_value_km/h                                                  2723.0
# PM1.0_µg/m³_ultrafine_particles_sensor                           2723.0
# PM1.0_µg/m³_atmos_env                                            2723.0
# PM2.5_µg/m³_atmos_env                                            2723.0
# PM10_µg/m³_atmos_env                                             2723.0
# GT_0.3um_in_0.1l_air                                             2723.0
# GT_0.5um_in_0.1l_air                                             2723.0
# GT_1.0um_in_0.1l_air                                             2723.0
# GT_2.5um_in_0.1l_air                                             2723.0
# GT_5.0um_in_0.1l_air                                             2723.0
# GT_10um_in_0.1l_air                                              2723.0
# CO2_in_ppm                                                       2723.0
# Temperature_in_c                                                 2723.0
# Relative_humidity                                                2723.0
# NO2_µg/m³_sensor                                                 2723.0
# Temp_value_°c                                                    2723.0
# NO_µg/m³_council                                                    NaN
# NOx_as_NO2_µg/m³_council                                            NaN
# NV10_µg/m³_council                                                  NaN
# NV2.5_µg/m³_council                                                 NaN
# V10_µg/m³_council                                                   NaN
# V2.5_µg/m³_council                                                  NaN
#
#                                                     Final Hourly Dataset Count  \
# PM2.5_µg/m³_combustion_particles_organic_compou...                        55.0
# PM2.5_mg/m³_aeroequal                                                     55.0
# PM2.5_µg/m³_council                                                       55.0
# PM10_µg/m³_dust_pollen_mould_spores_sensor                                55.0
# PM10_mg/m³_aeroequal                                                      55.0
# PM10_µg/m³_council                                                        55.0
# NO2_ppb_sensor                                                            55.0
# NO2_ppm_aeroequal                                                         55.0
# NO2_µg/m³_council                                                         55.0
# Wind_value_km/h                                                           55.0
# PM1.0_µg/m³_ultrafine_particles_sensor                                    55.0
# PM1.0_µg/m³_atmos_env                                                     55.0
# PM2.5_µg/m³_atmos_env                                                     55.0
# PM10_µg/m³_atmos_env                                                      55.0
# GT_0.3um_in_0.1l_air                                                      55.0
# GT_0.5um_in_0.1l_air                                                      55.0
# GT_1.0um_in_0.1l_air                                                      55.0
# GT_2.5um_in_0.1l_air                                                      55.0
# GT_5.0um_in_0.1l_air                                                      55.0
# GT_10um_in_0.1l_air                                                       55.0
# CO2_in_ppm                                                                55.0
# Temperature_in_c                                                          55.0
# Relative_humidity                                                         55.0
# NO2_µg/m³_sensor                                                          55.0
# Temp_value_°c                                                             55.0
# NO_µg/m³_council                                                          55.0
# NOx_as_NO2_µg/m³_council                                                  55.0
# NV10_µg/m³_council                                                        55.0
# NV2.5_µg/m³_council                                                       55.0
# V10_µg/m³_council                                                         55.0
# V2.5_µg/m³_council                                                        55.0
#
#                                                     Master Files Combined Count
# PM2.5_µg/m³_combustion_particles_organic_compou...                       2967.0
# PM2.5_mg/m³_aeroequal                                                    3047.0
# PM2.5_µg/m³_council                                                         NaN
# PM10_µg/m³_dust_pollen_mould_spores_sensor                               2967.0
# PM10_mg/m³_aeroequal                                                     3047.0
# PM10_µg/m³_council                                                          NaN
# NO2_ppb_sensor                                                           2636.0
# NO2_ppm_aeroequal                                                        3033.0
# NO2_µg/m³_council                                                           NaN
# Wind_value_km/h                                                          2723.0
# PM1.0_µg/m³_ultrafine_particles_sensor                                   2967.0
# PM1.0_µg/m³_atmos_env                                                    2967.0
# PM2.5_µg/m³_atmos_env                                                    2967.0
# PM10_µg/m³_atmos_env                                                     2967.0
# GT_0.3um_in_0.1l_air                                                     2967.0
# GT_0.5um_in_0.1l_air                                                     2967.0
# GT_1.0um_in_0.1l_air                                                     2967.0
# GT_2.5um_in_0.1l_air                                                     2967.0
# GT_5.0um_in_0.1l_air                                                     2967.0
# GT_10um_in_0.1l_air                                                      2967.0
# CO2_in_ppm                                                               2967.0
# Temperature_in_c                                                         2967.0
# Relative_humidity                                                        2967.0
# NO2_µg/m³_sensor                                                         2636.0
# Temp_value_°c                                                            2723.0
# NO_µg/m³_council                                                            NaN
# NOx_as_NO2_µg/m³_council                                                    NaN
# NV10_µg/m³_council                                                          NaN
# NV2.5_µg/m³_council                                                         NaN
# V10_µg/m³_council                                                           NaN
# V2.5_µg/m³_council                                                          NaN

# %%
comparison_mean = pd.DataFrame({
    'Final Dataset Mean': final_stats['mean'],
    'Final Hourly Dataset Mean': final_hourly_stats['mean'],
    'Master Files Combined Mean': master_stats_combined['mean']
})
comparison_mean.reindex(expected_columns)
# Out:
#                                                     Final Dataset Mean  \
# PM2.5_µg/m³_combustion_particles_organic_compou...           13.278186
# PM2.5_mg/m³_aeroequal                                         0.001366
# PM2.5_µg/m³_council                                                NaN
# PM10_µg/m³_dust_pollen_mould_spores_sensor                   15.506243
# PM10_mg/m³_aeroequal                                          0.003429
# PM10_µg/m³_council                                                 NaN
# NO2_ppb_sensor                                               -0.400421
# NO2_ppm_aeroequal                                             0.001492
# NO2_µg/m³_council                                                  NaN
# Wind_value_km/h                                               0.269152
# PM1.0_µg/m³_ultrafine_particles_sensor                        7.139736
# PM1.0_µg/m³_atmos_env                                         6.643592
# PM2.5_µg/m³_atmos_env                                        11.702534
# PM10_µg/m³_atmos_env                                         14.532501
# GT_0.3um_in_0.1l_air                                       1307.525707
# GT_0.5um_in_0.1l_air                                        390.327580
# GT_1.0um_in_0.1l_air                                        102.358245
# GT_2.5um_in_0.1l_air                                         12.779471
# GT_5.0um_in_0.1l_air                                          2.840250
# GT_10um_in_0.1l_air                                           2.221447
# CO2_in_ppm                                                  417.997506
# Temperature_in_c                                             24.991647
# Relative_humidity                                            51.418491
# NO2_µg/m³_sensor                                             -0.765806
# Temp_value_°c                                                23.297943
# NO_µg/m³_council                                                   NaN
# NOx_as_NO2_µg/m³_council                                           NaN
# NV10_µg/m³_council                                                 NaN
# NV2.5_µg/m³_council                                                NaN
# V10_µg/m³_council                                                  NaN
# V2.5_µg/m³_council                                                 NaN
#
#                                                     Final Hourly Dataset Mean  \
# PM2.5_µg/m³_combustion_particles_organic_compou...                  12.738731
# PM2.5_mg/m³_aeroequal                                                0.001292
# PM2.5_µg/m³_council                                                  8.789091
# PM10_µg/m³_dust_pollen_mould_spores_sensor                          14.935854
# PM10_mg/m³_aeroequal                                                 0.003314
# PM10_µg/m³_council                                                  17.118182
# NO2_ppb_sensor                                                      -0.485830
# NO2_ppm_aeroequal                                                    0.001950
# NO2_µg/m³_council                                                   14.023581
# Wind_value_km/h                                                      0.275688
# PM1.0_µg/m³_ultrafine_particles_sensor                               6.795935
# PM1.0_µg/m³_atmos_env                                                6.332602
# PM2.5_µg/m³_atmos_env                                               11.244378
# PM10_µg/m³_atmos_env                                                14.001860
# GT_0.3um_in_0.1l_air                                              1258.186158
# GT_0.5um_in_0.1l_air                                               375.992209
# GT_1.0um_in_0.1l_air                                                98.397636
# GT_2.5um_in_0.1l_air                                                12.451079
# GT_5.0um_in_0.1l_air                                                 2.831479
# GT_10um_in_0.1l_air                                                  2.169747
# CO2_in_ppm                                                         438.363253
# Temperature_in_c                                                    25.029859
# Relative_humidity                                                   51.808289
# NO2_µg/m³_sensor                                                    -0.929151
# Temp_value_°c                                                       23.234119
# NO_µg/m³_council                                                    13.324623
# NOx_as_NO2_µg/m³_council                                            34.454384
# NV10_µg/m³_council                                                  14.469091
# NV2.5_µg/m³_council                                                  8.094545
# V10_µg/m³_council                                                    2.654545
# V2.5_µg/m³_council                                                   0.698182
#
#                                                     Master Files Combined Mean
# PM2.5_µg/m³_combustion_particles_organic_compou...                   12.520728
# PM2.5_mg/m³_aeroequal                                                 0.001271
# PM2.5_µg/m³_council                                                        NaN
# PM10_µg/m³_dust_pollen_mould_spores_sensor                           14.752949
# PM10_mg/m³_aeroequal                                                  0.003208
# PM10_µg/m³_council                                                         NaN
# NO2_ppb_sensor                                                       -0.538546
# NO2_ppm_aeroequal                                                     0.001386
# NO2_µg/m³_council                                                          NaN
# Wind_value_km/h                                                       0.269152
# PM1.0_µg/m³_ultrafine_particles_sensor                                6.759353
# PM1.0_µg/m³_atmos_env                                                 6.310078
# PM2.5_µg/m³_atmos_env                                                11.094371
# PM10_µg/m³_atmos_env                                                 13.873273
# GT_0.3um_in_0.1l_air                                               1247.732053
# GT_0.5um_in_0.1l_air                                                372.411864
# GT_1.0um_in_0.1l_air                                                 97.201887
# GT_2.5um_in_0.1l_air                                                 12.096394
# GT_5.0um_in_0.1l_air                                                  2.834513
# GT_10um_in_0.1l_air                                                   2.262892
# CO2_in_ppm                                                          421.412737
# Temperature_in_c                                                     25.214156
# Relative_humidity                                                    50.929505
# NO2_µg/m³_sensor                                                     -1.029970
# Temp_value_°c                                                        23.297943
# NO_µg/m³_council                                                           NaN
# NOx_as_NO2_µg/m³_council                                                   NaN
# NV10_µg/m³_council                                                         NaN
# NV2.5_µg/m³_council                                                        NaN
# V10_µg/m³_council                                                          NaN
# V2.5_µg/m³_council                                                         NaN

# %%
comparison_std = pd.DataFrame({
    'Final Dataset Std Dev': final_stats['std'],
    'Final Hourly Dataset Std Dev': final_hourly_stats['std'],
    'Master Files Combined Std Dev': master_stats_combined['std']
}).reindex(expected_columns)
comparison_std.reindex(expected_columns)
# Out:
#                                                     Final Dataset Std Dev  \
# PM2.5_µg/m³_combustion_particles_organic_compou...              17.375500
# PM2.5_mg/m³_aeroequal                                            0.001564
# PM2.5_µg/m³_council                                                   NaN
# PM10_µg/m³_dust_pollen_mould_spores_sensor                      19.040585
# PM10_mg/m³_aeroequal                                             0.005312
# PM10_µg/m³_council                                                    NaN
# NO2_ppb_sensor                                                   2.427300
# NO2_ppm_aeroequal                                                0.002703
# NO2_µg/m³_council                                                     NaN
# Wind_value_km/h                                                  0.576094
# PM1.0_µg/m³_ultrafine_particles_sensor                           8.753120
# PM1.0_µg/m³_atmos_env                                            7.446158
# PM2.5_µg/m³_atmos_env                                           13.181124
# PM10_µg/m³_atmos_env                                            16.406246
# GT_0.3um_in_0.1l_air                                          1423.979490
# GT_0.5um_in_0.1l_air                                           428.503022
# GT_1.0um_in_0.1l_air                                           135.904285
# GT_2.5um_in_0.1l_air                                            16.856321
# GT_5.0um_in_0.1l_air                                             3.084841
# GT_10um_in_0.1l_air                                              2.673218
# CO2_in_ppm                                                      69.351263
# Temperature_in_c                                                 1.389032
# Relative_humidity                                                6.825561
# NO2_µg/m³_sensor                                                 4.642212
# Temp_value_°c                                                    1.656689
# NO_µg/m³_council                                                      NaN
# NOx_as_NO2_µg/m³_council                                              NaN
# NV10_µg/m³_council                                                    NaN
# NV2.5_µg/m³_council                                                   NaN
# V10_µg/m³_council                                                     NaN
# V2.5_µg/m³_council                                                    NaN
#
#                                                     Final Hourly Dataset Std Dev  \
# PM2.5_µg/m³_combustion_particles_organic_compou...                     16.939382
# PM2.5_mg/m³_aeroequal                                                   0.001386
# PM2.5_µg/m³_council                                                     7.651450
# PM10_µg/m³_dust_pollen_mould_spores_sensor                             18.538678
# PM10_mg/m³_aeroequal                                                    0.002926
# PM10_µg/m³_council                                                      9.930725
# NO2_ppb_sensor                                                          1.860480
# NO2_ppm_aeroequal                                                       0.003165
# NO2_µg/m³_council                                                       4.581423
# Wind_value_km/h                                                         0.263145
# PM1.0_µg/m³_ultrafine_particles_sensor                                  8.488992
# PM1.0_µg/m³_atmos_env                                                   7.235916
# PM2.5_µg/m³_atmos_env                                                  12.842817
# PM10_µg/m³_atmos_env                                                   15.949654
# GT_0.3um_in_0.1l_air                                                 1390.457257
# GT_0.5um_in_0.1l_air                                                  418.012283
# GT_1.0um_in_0.1l_air                                                  132.374126
# GT_2.5um_in_0.1l_air                                                   16.130712
# GT_5.0um_in_0.1l_air                                                    2.412451
# GT_10um_in_0.1l_air                                                     1.984692
# CO2_in_ppm                                                            153.177280
# Temperature_in_c                                                        1.419433
# Relative_humidity                                                       7.046765
# NO2_µg/m³_sensor                                                        3.558168
# Temp_value_°c                                                           1.638058
# NO_µg/m³_council                                                        7.337301
# NOx_as_NO2_µg/m³_council                                               12.997356
# NV10_µg/m³_council                                                      9.272957
# NV2.5_µg/m³_council                                                     7.238463
# V10_µg/m³_council                                                       2.776677
# V2.5_µg/m³_council                                                      1.772474
#
#                                                     Master Files Combined Std Dev
# PM2.5_µg/m³_combustion_particles_organic_compou...                      16.736268
# PM2.5_mg/m³_aeroequal                                                    0.001514
# PM2.5_µg/m³_council                                                           NaN
# PM10_µg/m³_dust_pollen_mould_spores_sensor                              18.295856
# PM10_mg/m³_aeroequal                                                     0.005124
# PM10_µg/m³_council                                                            NaN
# NO2_ppb_sensor                                                           2.528475
# NO2_ppm_aeroequal                                                        0.002795
# NO2_µg/m³_council                                                             NaN
# Wind_value_km/h                                                          0.576094
# PM1.0_µg/m³_ultrafine_particles_sensor                                   8.436670
# PM1.0_µg/m³_atmos_env                                                    7.180993
# PM2.5_µg/m³_atmos_env                                                   12.708007
# PM10_µg/m³_atmos_env                                                    15.769607
# GT_0.3um_in_0.1l_air                                                  1370.214496
# GT_0.5um_in_0.1l_air                                                   412.282652
# GT_1.0um_in_0.1l_air                                                   130.626369
# GT_2.5um_in_0.1l_air                                                    16.188272
# GT_5.0um_in_0.1l_air                                                     2.992334
# GT_10um_in_0.1l_air                                                      2.624830
# CO2_in_ppm                                                              82.076182
# Temperature_in_c                                                         1.502765
# Relative_humidity                                                        6.838796
# NO2_µg/m³_sensor                                                         4.835709
# Temp_value_°c                                                            1.656689
# NO_µg/m³_council                                                              NaN
# NOx_as_NO2_µg/m³_council                                                      NaN
# NV10_µg/m³_council                                                            NaN
# NV2.5_µg/m³_council                                                           NaN
# V10_µg/m³_council                                                             NaN
# V2.5_µg/m³_council                                                            NaN

# %%
comparison_min = pd.DataFrame({
    'Final Dataset Min': final_stats['min'],
    'Final Hourly Dataset Min': final_hourly_stats['min'],
    'Master Files Combined Min': master_stats_combined['min']
})
comparison_min.reindex(expected_columns)
# Out:
#                                                     Final Dataset Min  \
# PM2.5_µg/m³_combustion_particles_organic_compou...           0.000000
# PM2.5_mg/m³_aeroequal                                        0.000000
# PM2.5_µg/m³_council                                               NaN
# PM10_µg/m³_dust_pollen_mould_spores_sensor                   0.000000
# PM10_mg/m³_aeroequal                                         0.000000
# PM10_µg/m³_council                                                NaN
# NO2_ppb_sensor                                             -63.952923
# NO2_ppm_aeroequal                                            0.000000
# NO2_µg/m³_council                                                 NaN
# Wind_value_km/h                                              0.000000
# PM1.0_µg/m³_ultrafine_particles_sensor                       0.000000
# PM1.0_µg/m³_atmos_env                                        0.000000
# PM2.5_µg/m³_atmos_env                                        0.000000
# PM10_µg/m³_atmos_env                                         0.000000
# GT_0.3um_in_0.1l_air                                       135.000000
# GT_0.5um_in_0.1l_air                                        37.000000
# GT_1.0um_in_0.1l_air                                         4.000000
# GT_2.5um_in_0.1l_air                                         0.000000
# GT_5.0um_in_0.1l_air                                         0.000000
# GT_10um_in_0.1l_air                                          0.000000
# CO2_in_ppm                                                 208.270000
# Temperature_in_c                                            22.470000
# Relative_humidity                                           38.990000
# NO2_µg/m³_sensor                                          -122.309959
# Temp_value_°c                                               19.700000
# NO_µg/m³_council                                                  NaN
# NOx_as_NO2_µg/m³_council                                          NaN
# NV10_µg/m³_council                                                NaN
# NV2.5_µg/m³_council                                               NaN
# V10_µg/m³_council                                                 NaN
# V2.5_µg/m³_council                                                NaN
#
#                                                     Final Hourly Dataset Min  \
# PM2.5_µg/m³_combustion_particles_organic_compou...                  0.750000
# PM2.5_mg/m³_aeroequal                                               0.000083
# PM2.5_µg/m³_council                                                -1.000000
# PM10_µg/m³_dust_pollen_mould_spores_sensor                          1.600000
# PM10_mg/m³_aeroequal                                                0.000485
# PM10_µg/m³_council                                                  0.000000
# NO2_ppb_sensor                                                     -5.703395
# NO2_ppm_aeroequal                                                   0.000000
# NO2_µg/m³_council                                                   7.975130
# Wind_value_km/h                                                     0.000000
# PM1.0_µg/m³_ultrafine_particles_sensor                              0.000000
# PM1.0_µg/m³_atmos_env                                               0.000000
# PM2.5_µg/m³_atmos_env                                               0.750000
# PM10_µg/m³_atmos_env                                                1.600000
# GT_0.3um_in_0.1l_air                                              193.700000
# GT_0.5um_in_0.1l_air                                               52.150000
# GT_1.0um_in_0.1l_air                                               10.800000
# GT_2.5um_in_0.1l_air                                                1.000000
# GT_5.0um_in_0.1l_air                                                0.000000
# GT_10um_in_0.1l_air                                                 0.000000
# CO2_in_ppm                                                        305.642500
# Temperature_in_c                                                   22.908833
# Relative_humidity                                                  41.007188
# NO2_µg/m³_sensor                                                  -10.907743
# Temp_value_°c                                                      19.819231
# NO_µg/m³_council                                                    7.019180
# NOx_as_NO2_µg/m³_council                                           18.737720
# NV10_µg/m³_council                                                  0.000000
# NV2.5_µg/m³_council                                                 0.000000
# V10_µg/m³_council                                                  -7.100000
# V2.5_µg/m³_council                                                 -3.100000
#
#                                                     Master Files Combined Min
# PM2.5_µg/m³_combustion_particles_organic_compou...                   0.000000
# PM2.5_mg/m³_aeroequal                                                0.000000
# PM2.5_µg/m³_council                                                       NaN
# PM10_µg/m³_dust_pollen_mould_spores_sensor                           0.000000
# PM10_mg/m³_aeroequal                                                 0.000000
# PM10_µg/m³_council                                                        NaN
# NO2_ppb_sensor                                                     -63.952923
# NO2_ppm_aeroequal                                                    0.000000
# NO2_µg/m³_council                                                         NaN
# Wind_value_km/h                                                      0.000000
# PM1.0_µg/m³_ultrafine_particles_sensor                               0.000000
# PM1.0_µg/m³_atmos_env                                                0.000000
# PM2.5_µg/m³_atmos_env                                                0.000000
# PM10_µg/m³_atmos_env                                                 0.000000
# GT_0.3um_in_0.1l_air                                               135.000000
# GT_0.5um_in_0.1l_air                                                37.000000
# GT_1.0um_in_0.1l_air                                                 4.000000
# GT_2.5um_in_0.1l_air                                                 0.000000
# GT_5.0um_in_0.1l_air                                                 0.000000
# GT_10um_in_0.1l_air                                                  0.000000
# CO2_in_ppm                                                         208.270000
# Temperature_in_c                                                    22.470000
# Relative_humidity                                                   38.990000
# NO2_µg/m³_sensor                                                  -122.309959
# Temp_value_°c                                                       19.700000
# NO_µg/m³_council                                                          NaN
# NOx_as_NO2_µg/m³_council                                                  NaN
# NV10_µg/m³_council                                                        NaN
# NV2.5_µg/m³_council                                                       NaN
# V10_µg/m³_council                                                         NaN
# V2.5_µg/m³_council                                                        NaN

# %%
comparison_25 = pd.DataFrame({
    'Final Dataset 25%': final_stats['25%'],
    'Final Hourly Dataset 25%': final_hourly_stats['25%'],
    'Master Files Combined 25%': master_stats_combined['25%']
})
comparison_25.reindex(expected_columns)
# Out:
#                                                     Final Dataset 25%  \
# PM2.5_µg/m³_combustion_particles_organic_compou...           4.000000
# PM2.5_mg/m³_aeroequal                                        0.000000
# PM2.5_µg/m³_council                                               NaN
# PM10_µg/m³_dust_pollen_mould_spores_sensor                   5.000000
# PM10_mg/m³_aeroequal                                         0.000000
# PM10_µg/m³_council                                                NaN
# NO2_ppb_sensor                                              -1.607338
# NO2_ppm_aeroequal                                            0.000000
# NO2_µg/m³_council                                                 NaN
# Wind_value_km/h                                              0.000000
# PM1.0_µg/m³_ultrafine_particles_sensor                       3.000000
# PM1.0_µg/m³_atmos_env                                        3.000000
# PM2.5_µg/m³_atmos_env                                        4.000000
# PM10_µg/m³_atmos_env                                         5.000000
# GT_0.3um_in_0.1l_air                                       570.000000
# GT_0.5um_in_0.1l_air                                       169.000000
# GT_1.0um_in_0.1l_air                                        31.000000
# GT_2.5um_in_0.1l_air                                         2.000000
# GT_5.0um_in_0.1l_air                                         0.000000
# GT_10um_in_0.1l_air                                          0.000000
# CO2_in_ppm                                                 381.500000
# Temperature_in_c                                            23.930000
# Relative_humidity                                           45.410000
# NO2_µg/m³_sensor                                            -3.074033
# Temp_value_°c                                               22.200000
# NO_µg/m³_council                                                  NaN
# NOx_as_NO2_µg/m³_council                                          NaN
# NV10_µg/m³_council                                                NaN
# NV2.5_µg/m³_council                                               NaN
# V10_µg/m³_council                                                 NaN
# V2.5_µg/m³_council                                                NaN
#
#                                                     Final Hourly Dataset 25%  \
# PM2.5_µg/m³_combustion_particles_organic_compou...                  4.608333
# PM2.5_mg/m³_aeroequal                                               0.000442
# PM2.5_µg/m³_council                                                 4.150000
# PM10_µg/m³_dust_pollen_mould_spores_sensor                          5.798023
# PM10_mg/m³_aeroequal                                                0.001255
# PM10_µg/m³_council                                                 10.800000
# NO2_ppb_sensor                                                     -1.661391
# NO2_ppm_aeroequal                                                   0.000000
# NO2_µg/m³_council                                                  10.870170
# Wind_value_km/h                                                     0.081667
# PM1.0_µg/m³_ultrafine_particles_sensor                              2.710417
# PM1.0_µg/m³_atmos_env                                               2.710417
# PM2.5_µg/m³_atmos_env                                               4.608333
# PM10_µg/m³_atmos_env                                                5.798023
# GT_0.3um_in_0.1l_air                                              622.025000
# GT_0.5um_in_0.1l_air                                              186.712429
# GT_1.0um_in_0.1l_air                                               32.800000
# GT_2.5um_in_0.1l_air                                                3.850000
# GT_5.0um_in_0.1l_air                                                1.053333
# GT_10um_in_0.1l_air                                                 0.966667
# CO2_in_ppm                                                        390.520443
# Temperature_in_c                                                   23.967995
# Relative_humidity                                                  46.116833
# NO2_µg/m³_sensor                                                   -3.177409
# Temp_value_°c                                                      22.207500
# NO_µg/m³_council                                                   10.248130
# NOx_as_NO2_µg/m³_council                                           28.065940
# NV10_µg/m³_council                                                  9.100000
# NV2.5_µg/m³_council                                                 3.400000
# V10_µg/m³_council                                                   0.800000
# V2.5_µg/m³_council                                                 -0.350000
#
#                                                     Master Files Combined 25%
# PM2.5_µg/m³_combustion_particles_organic_compou...                   4.000000
# PM2.5_mg/m³_aeroequal                                                0.000000
# PM2.5_µg/m³_council                                                       NaN
# PM10_µg/m³_dust_pollen_mould_spores_sensor                           5.000000
# PM10_mg/m³_aeroequal                                                 0.000000
# PM10_µg/m³_council                                                        NaN
# NO2_ppb_sensor                                                      -2.137721
# NO2_ppm_aeroequal                                                    0.000000
# NO2_µg/m³_council                                                         NaN
# Wind_value_km/h                                                      0.000000
# PM1.0_µg/m³_ultrafine_particles_sensor                               3.000000
# PM1.0_µg/m³_atmos_env                                                3.000000
# PM2.5_µg/m³_atmos_env                                                4.000000
# PM10_µg/m³_atmos_env                                                 5.000000
# GT_0.3um_in_0.1l_air                                               600.000000
# GT_0.5um_in_0.1l_air                                               180.000000
# GT_1.0um_in_0.1l_air                                                34.000000
# GT_2.5um_in_0.1l_air                                                 4.000000
# GT_5.0um_in_0.1l_air                                                 0.000000
# GT_10um_in_0.1l_air                                                  0.000000
# CO2_in_ppm                                                         384.080000
# Temperature_in_c                                                    24.030000
# Relative_humidity                                                   45.110000
# NO2_µg/m³_sensor                                                    -4.088391
# Temp_value_°c                                                       22.200000
# NO_µg/m³_council                                                          NaN
# NOx_as_NO2_µg/m³_council                                                  NaN
# NV10_µg/m³_council                                                        NaN
# NV2.5_µg/m³_council                                                       NaN
# V10_µg/m³_council                                                         NaN
# V2.5_µg/m³_council                                                        NaN

# %%
comparison_50 = pd.DataFrame({
    'Final Dataset 50%': final_stats['50%'],
    'Final Hourly Dataset 50%': final_hourly_stats['50%'],
    'Master Files Combined 50%': master_stats_combined['50%']
})
comparison_50.reindex(expected_columns)
# Out:
#                                                     Final Dataset 50%  \
# PM2.5_µg/m³_combustion_particles_organic_compou...           7.000000
# PM2.5_mg/m³_aeroequal                                        0.001000
# PM2.5_µg/m³_council                                               NaN
# PM10_µg/m³_dust_pollen_mould_spores_sensor                   9.000000
# PM10_mg/m³_aeroequal                                         0.001000
# PM10_µg/m³_council                                                NaN
# NO2_ppb_sensor                                               0.022329
# NO2_ppm_aeroequal                                            0.000000
# NO2_µg/m³_council                                                 NaN
# Wind_value_km/h                                              0.000000
# PM1.0_µg/m³_ultrafine_particles_sensor                       4.000000
# PM1.0_µg/m³_atmos_env                                        4.000000
# PM2.5_µg/m³_atmos_env                                        7.000000
# PM10_µg/m³_atmos_env                                         9.000000
# GT_0.3um_in_0.1l_air                                       828.000000
# GT_0.5um_in_0.1l_air                                       243.000000
# GT_1.0um_in_0.1l_air                                        51.000000
# GT_2.5um_in_0.1l_air                                         6.000000
# GT_5.0um_in_0.1l_air                                         2.000000
# GT_10um_in_0.1l_air                                          2.000000
# CO2_in_ppm                                                 409.740000
# Temperature_in_c                                            24.820000
# Relative_humidity                                           49.930000
# NO2_µg/m³_sensor                                             0.042704
# Temp_value_°c                                               22.900000
# NO_µg/m³_council                                                  NaN
# NOx_as_NO2_µg/m³_council                                          NaN
# NV10_µg/m³_council                                                NaN
# NV2.5_µg/m³_council                                               NaN
# V10_µg/m³_council                                                 NaN
# V2.5_µg/m³_council                                                NaN
#
#                                                     Final Hourly Dataset 50%  \
# PM2.5_µg/m³_combustion_particles_organic_compou...                  7.133333
# PM2.5_mg/m³_aeroequal                                               0.000700
# PM2.5_µg/m³_council                                                 5.900000
# PM10_µg/m³_dust_pollen_mould_spores_sensor                          8.250000
# PM10_mg/m³_aeroequal                                                0.002200
# PM10_µg/m³_council                                                 14.100000
# NO2_ppb_sensor                                                     -0.005002
# NO2_ppm_aeroequal                                                   0.000217
# NO2_µg/m³_council                                                  12.761160
# Wind_value_km/h                                                     0.181667
# PM1.0_µg/m³_ultrafine_particles_sensor                              3.800000
# PM1.0_µg/m³_atmos_env                                               3.800000
# PM2.5_µg/m³_atmos_env                                               7.133333
# PM10_µg/m³_atmos_env                                                8.250000
# GT_0.3um_in_0.1l_air                                              810.150000
# GT_0.5um_in_0.1l_air                                              236.800000
# GT_1.0um_in_0.1l_air                                               50.600000
# GT_2.5um_in_0.1l_air                                                6.705882
# GT_5.0um_in_0.1l_air                                                2.000000
# GT_10um_in_0.1l_air                                                 1.533333
# CO2_in_ppm                                                        415.995294
# Temperature_in_c                                                   24.751667
# Relative_humidity                                                  50.058500
# NO2_µg/m³_sensor                                                   -0.009566
# Temp_value_°c                                                      23.146667
# NO_µg/m³_council                                                   12.616440
# NOx_as_NO2_µg/m³_council                                           31.518000
# NV10_µg/m³_council                                                 12.800000
# NV2.5_µg/m³_council                                                 5.400000
# V10_µg/m³_council                                                   2.800000
# V2.5_µg/m³_council                                                  0.600000
#
#                                                     Master Files Combined 50%
# PM2.5_µg/m³_combustion_particles_organic_compou...                   7.000000
# PM2.5_mg/m³_aeroequal                                                0.001000
# PM2.5_µg/m³_council                                                       NaN
# PM10_µg/m³_dust_pollen_mould_spores_sensor                           9.000000
# PM10_mg/m³_aeroequal                                                 0.001000
# PM10_µg/m³_council                                                        NaN
# NO2_ppb_sensor                                                      -0.024992
# NO2_ppm_aeroequal                                                    0.000000
# NO2_µg/m³_council                                                         NaN
# Wind_value_km/h                                                      0.000000
# PM1.0_µg/m³_ultrafine_particles_sensor                               4.000000
# PM1.0_µg/m³_atmos_env                                                4.000000
# PM2.5_µg/m³_atmos_env                                                7.000000
# PM10_µg/m³_atmos_env                                                 9.000000
# GT_0.3um_in_0.1l_air                                               801.000000
# GT_0.5um_in_0.1l_air                                               236.000000
# GT_1.0um_in_0.1l_air                                                50.000000
# GT_2.5um_in_0.1l_air                                                 6.000000
# GT_5.0um_in_0.1l_air                                                 2.000000
# GT_10um_in_0.1l_air                                                  2.000000
# CO2_in_ppm                                                         413.270000
# Temperature_in_c                                                    24.980000
# Relative_humidity                                                   49.300000
# NO2_µg/m³_sensor                                                    -0.047797
# Temp_value_°c                                                       22.900000
# NO_µg/m³_council                                                          NaN
# NOx_as_NO2_µg/m³_council                                                  NaN
# NV10_µg/m³_council                                                        NaN
# NV2.5_µg/m³_council                                                       NaN
# V10_µg/m³_council                                                         NaN
# V2.5_µg/m³_council                                                        NaN

# %%
comparison_75 = pd.DataFrame({
    'Final Dataset 75%': final_stats['75%'],
    'Final Hourly Dataset 75%': final_hourly_stats['75%'],
    'Master Files Combined 75%': master_stats_combined['75%']
})
comparison_75.reindex(expected_columns)
# Out:
#                                                     Final Dataset 75%  \
# PM2.5_µg/m³_combustion_particles_organic_compou...          11.000000
# PM2.5_mg/m³_aeroequal                                        0.002000
# PM2.5_µg/m³_council                                               NaN
# PM10_µg/m³_dust_pollen_mould_spores_sensor                  14.000000
# PM10_mg/m³_aeroequal                                         0.004000
# PM10_µg/m³_council                                                NaN
# NO2_ppb_sensor                                               0.743057
# NO2_ppm_aeroequal                                            0.002750
# NO2_µg/m³_council                                                 NaN
# Wind_value_km/h                                              0.300000
# PM1.0_µg/m³_ultrafine_particles_sensor                       6.000000
# PM1.0_µg/m³_atmos_env                                        6.000000
# PM2.5_µg/m³_atmos_env                                       11.000000
# PM10_µg/m³_atmos_env                                        14.000000
# GT_0.3um_in_0.1l_air                                      1131.000000
# GT_0.5um_in_0.1l_air                                       341.000000
# GT_1.0um_in_0.1l_air                                        76.000000
# GT_2.5um_in_0.1l_air                                        12.000000
# GT_5.0um_in_0.1l_air                                         4.000000
# GT_10um_in_0.1l_air                                          4.000000
# CO2_in_ppm                                                 438.630000
# Temperature_in_c                                            25.900000
# Relative_humidity                                           56.410000
# NO2_µg/m³_sensor                                             1.421096
# Temp_value_°c                                               24.600000
# NO_µg/m³_council                                                  NaN
# NOx_as_NO2_µg/m³_council                                          NaN
# NV10_µg/m³_council                                                NaN
# NV2.5_µg/m³_council                                               NaN
# V10_µg/m³_council                                                 NaN
# V2.5_µg/m³_council                                                NaN
#
#                                                     Final Hourly Dataset 75%  \
# PM2.5_µg/m³_combustion_particles_organic_compou...                  9.383333
# PM2.5_mg/m³_aeroequal                                               0.001608
# PM2.5_µg/m³_council                                                11.100000
# PM10_µg/m³_dust_pollen_mould_spores_sensor                         11.641667
# PM10_mg/m³_aeroequal                                                0.003850
# PM10_µg/m³_council                                                 22.100000
# NO2_ppb_sensor                                                      0.759264
# NO2_ppm_aeroequal                                                   0.003613
# NO2_µg/m³_council                                                  15.347815
# Wind_value_km/h                                                     0.459167
# PM1.0_µg/m³_ultrafine_particles_sensor                              5.723529
# PM1.0_µg/m³_atmos_env                                               5.723529
# PM2.5_µg/m³_atmos_env                                               9.383333
# PM10_µg/m³_atmos_env                                               11.641667
# GT_0.3um_in_0.1l_air                                             1010.175000
# GT_0.5um_in_0.1l_air                                              302.450000
# GT_1.0um_in_0.1l_air                                               63.731250
# GT_2.5um_in_0.1l_air                                               11.416667
# GT_5.0um_in_0.1l_air                                                4.050000
# GT_10um_in_0.1l_air                                                 3.056250
# CO2_in_ppm                                                        446.670750
# Temperature_in_c                                                   26.009908
# Relative_humidity                                                  57.397250
# NO2_µg/m³_sensor                                                    1.452093
# Temp_value_°c                                                      24.305985
# NO_µg/m³_council                                                   14.513895
# NOx_as_NO2_µg/m³_council                                           37.461095
# NV10_µg/m³_council                                                 18.700000
# NV2.5_µg/m³_council                                                10.450000
# V10_µg/m³_council                                                   4.400000
# V2.5_µg/m³_council                                                  1.800000
#
#                                                     Master Files Combined 75%
# PM2.5_µg/m³_combustion_particles_organic_compou...                  10.000000
# PM2.5_mg/m³_aeroequal                                                0.002000
# PM2.5_µg/m³_council                                                       NaN
# PM10_µg/m³_dust_pollen_mould_spores_sensor                          12.000000
# PM10_mg/m³_aeroequal                                                 0.004000
# PM10_µg/m³_council                                                        NaN
# NO2_ppb_sensor                                                       0.725745
# NO2_ppm_aeroequal                                                    0.002000
# NO2_µg/m³_council                                                         NaN
# Wind_value_km/h                                                      0.300000
# PM1.0_µg/m³_ultrafine_particles_sensor                               6.000000
# PM1.0_µg/m³_atmos_env                                                6.000000
# PM2.5_µg/m³_atmos_env                                               10.000000
# PM10_µg/m³_atmos_env                                                12.000000
# GT_0.3um_in_0.1l_air                                              1068.000000
# GT_0.5um_in_0.1l_air                                               318.000000
# GT_1.0um_in_0.1l_air                                                71.000000
# GT_2.5um_in_0.1l_air                                                12.000000
# GT_5.0um_in_0.1l_air                                                 4.000000
# GT_10um_in_0.1l_air                                                  4.000000
# CO2_in_ppm                                                         442.215000
# Temperature_in_c                                                    26.465000
# Relative_humidity                                                   55.555000
# NO2_µg/m³_sensor                                                     1.387987
# Temp_value_°c                                                       24.600000
# NO_µg/m³_council                                                          NaN
# NOx_as_NO2_µg/m³_council                                                  NaN
# NV10_µg/m³_council                                                        NaN
# NV2.5_µg/m³_council                                                       NaN
# V10_µg/m³_council                                                         NaN
# V2.5_µg/m³_council                                                        NaN

# %%
comparison_max = pd.DataFrame({
    'Final Dataset Max': final_stats['max'],
    'Final Hourly Dataset Max': final_hourly_stats['max'],
    'Master Files Combined Max': master_stats_combined['max']
})
comparison_max.reindex(expected_columns)
# Out:
#                                                     Final Dataset Max  \
# PM2.5_µg/m³_combustion_particles_organic_compou...          70.000000
# PM2.5_mg/m³_aeroequal                                        0.008000
# PM2.5_µg/m³_council                                               NaN
# PM10_µg/m³_dust_pollen_mould_spores_sensor                  80.000000
# PM10_mg/m³_aeroequal                                         0.097000
# PM10_µg/m³_council                                                NaN
# NO2_ppb_sensor                                              12.758244
# NO2_ppm_aeroequal                                            0.030000
# NO2_µg/m³_council                                                 NaN
# Wind_value_km/h                                              4.300000
# PM1.0_µg/m³_ultrafine_particles_sensor                      34.000000
# PM1.0_µg/m³_atmos_env                                       28.000000
# PM2.5_µg/m³_atmos_env                                       50.000000
# PM10_µg/m³_atmos_env                                        64.000000
# GT_0.3um_in_0.1l_air                                      5535.000000
# GT_0.5um_in_0.1l_air                                      1663.000000
# GT_1.0um_in_0.1l_air                                       553.000000
# GT_2.5um_in_0.1l_air                                        84.000000
# GT_5.0um_in_0.1l_air                                        20.000000
# GT_10um_in_0.1l_air                                         18.000000
# CO2_in_ppm                                                1669.060000
# Temperature_in_c                                            28.660000
# Relative_humidity                                           66.190000
# NO2_µg/m³_sensor                                            24.400144
# Temp_value_°c                                               30.100000
# NO_µg/m³_council                                                  NaN
# NOx_as_NO2_µg/m³_council                                          NaN
# NV10_µg/m³_council                                                NaN
# NV2.5_µg/m³_council                                               NaN
# V10_µg/m³_council                                                 NaN
# V2.5_µg/m³_council                                                NaN
#
#                                                     Final Hourly Dataset Max  \
# PM2.5_µg/m³_combustion_particles_organic_compou...                 62.800000
# PM2.5_mg/m³_aeroequal                                               0.005183
# PM2.5_µg/m³_council                                                30.000000
# PM10_µg/m³_dust_pollen_mould_spores_sensor                         70.750000
# PM10_mg/m³_aeroequal                                                0.011383
# PM10_µg/m³_council                                                 49.700000
# NO2_ppb_sensor                                                      4.027257
# NO2_ppm_aeroequal                                                   0.016950
# NO2_µg/m³_council                                                  28.128090
# Wind_value_km/h                                                     0.956250
# PM1.0_µg/m³_ultrafine_particles_sensor                             31.500000
# PM1.0_µg/m³_atmos_env                                              26.333333
# PM2.5_µg/m³_atmos_env                                              46.466667
# PM10_µg/m³_atmos_env                                               59.766667
# GT_0.3um_in_0.1l_air                                             5253.100000
# GT_0.5um_in_0.1l_air                                             1575.833333
# GT_1.0um_in_0.1l_air                                              498.900000
# GT_2.5um_in_0.1l_air                                               64.545455
# GT_5.0um_in_0.1l_air                                               10.727273
# GT_10um_in_0.1l_air                                                 9.200000
# CO2_in_ppm                                                       1503.564000
# Temperature_in_c                                                   28.453437
# Relative_humidity                                                  64.621250
# NO2_µg/m³_sensor                                                    7.702130
# Temp_value_°c                                                      26.621875
# NO_µg/m³_council                                                   62.128010
# NOx_as_NO2_µg/m³_council                                          106.507130
# NV10_µg/m³_council                                                 44.400000
# NV2.5_µg/m³_council                                                28.200000
# V10_µg/m³_council                                                   7.500000
# V2.5_µg/m³_council                                                  4.500000
#
#                                                     Master Files Combined Max
# PM2.5_µg/m³_combustion_particles_organic_compou...                  70.000000
# PM2.5_mg/m³_aeroequal                                                0.008000
# PM2.5_µg/m³_council                                                       NaN
# PM10_µg/m³_dust_pollen_mould_spores_sensor                          80.000000
# PM10_mg/m³_aeroequal                                                 0.097000
# PM10_µg/m³_council                                                        NaN
# NO2_ppb_sensor                                                      12.758244
# NO2_ppm_aeroequal                                                    0.031000
# NO2_µg/m³_council                                                         NaN
# Wind_value_km/h                                                      4.300000
# PM1.0_µg/m³_ultrafine_particles_sensor                              34.000000
# PM1.0_µg/m³_atmos_env                                               28.000000
# PM2.5_µg/m³_atmos_env                                               50.000000
# PM10_µg/m³_atmos_env                                                64.000000
# GT_0.3um_in_0.1l_air                                              5535.000000
# GT_0.5um_in_0.1l_air                                              1663.000000
# GT_1.0um_in_0.1l_air                                               553.000000
# GT_2.5um_in_0.1l_air                                                84.000000
# GT_5.0um_in_0.1l_air                                                20.000000
# GT_10um_in_0.1l_air                                                 18.000000
# CO2_in_ppm                                                        1713.720000
# Temperature_in_c                                                    30.980000
# Relative_humidity                                                   66.950000
# NO2_µg/m³_sensor                                                    24.400144
# Temp_value_°c                                                       30.100000
# NO_µg/m³_council                                                          NaN
# NOx_as_NO2_µg/m³_council                                                  NaN
# NV10_µg/m³_council                                                        NaN
# NV2.5_µg/m³_council                                                       NaN
# V10_µg/m³_council                                                         NaN
# V2.5_µg/m³_council                                                        NaN
